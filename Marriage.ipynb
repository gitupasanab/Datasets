# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('marriage_data_india.csv')

# %%
df
# Out:
#          ID Marriage_Type  Age_at_Marriage  Gender Education_Level  \
# 0         1          Love               23    Male        Graduate
# 1         2          Love               28  Female          School
# 2         3      Arranged               39    Male    Postgraduate
# 3         4      Arranged               26  Female          School
# 4         5          Love               32  Female        Graduate
# ...     ...           ...              ...     ...             ...
# 9995   9996          Love               25    Male    Postgraduate
# 9996   9997      Arranged               31  Female          School
# 9997   9998          Love               22    Male        Graduate
# 9998   9999      Arranged               39    Male    Postgraduate
# 9999  10000      Arranged               36    Male          School
#
#      Caste_Match Religion Parental_Approval Urban_Rural Dowry_Exchanged  \
# 0      Different    Hindu                No       Urban              No
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# Marriage_Type           0
# Age_at_Marriage         0
# Gender                  0
# Education_Level         0
# Caste_Match             0
# Religion                0
# Parental_Approval       0
# Urban_Rural             0
# Dowry_Exchanged         0
# Marital_Satisfaction    0
# Divorce_Status          0
# Children_Count          0
# Income_Level            0
# Years_Since_Marriage    0
# Spouse_Working          0
# Inter-Caste             0
# Inter-Religion          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Marriage_Type', 'Age_at_Marriage', 'Gender', 'Education_Level',
#        'Caste_Match', 'Religion', 'Parental_Approval', 'Urban_Rural',
#        'Dowry_Exchanged', 'Marital_Satisfaction', 'Divorce_Status',
#        'Children_Count', 'Income_Level', 'Years_Since_Marriage',
#        'Spouse_Working', 'Inter-Caste', 'Inter-Religion'],
#       dtype='object')

# %%
# UNIVARIATE ANALYSIS

# %%
# NUMERICAL

# %%
df['Age_at_Marriage'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Age_at_Marriage'].describe()
# Out:
# count    10000.000000
# mean        28.503800
# std          6.279564
# min         18.000000
# 25%         23.000000
# 50%         29.000000
# 75%         34.000000
# max         39.000000
# Name: Age_at_Marriage, dtype: float64

# %%
df['Age_at_Marriage'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age_at_Marriage'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age_at_Marriage'].skew()
# Out:
# np.float64(-0.011110765950348907)

# %%
df['Age_at_Marriage'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Years_Since_Marriage'].describe()
# Out:
# count    10000.000000
# mean        24.973800
# std         14.054838
# min          1.000000
# 25%         13.000000
# 50%         25.000000
# 75%         37.000000
# max         49.000000
# Name: Years_Since_Marriage, dtype: float64

# %%
df['Years_Since_Marriage'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Years_Since_Marriage'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Years_Since_Marriage'].skew()
# Out:
# np.float64(-0.004588663482379904)

# %%
df['Years_Since_Marriage'].plot(kind='box')
# Out:
# <Axes: >

# %%
# CATEGORIACL

# %%
df
# Out:
#          ID Marriage_Type  Age_at_Marriage  Gender Education_Level  \
# 0         1          Love               23    Male        Graduate
# 1         2          Love               28  Female          School
# 2         3      Arranged               39    Male    Postgraduate
# 3         4      Arranged               26  Female          School
# 4         5          Love               32  Female        Graduate
# ...     ...           ...              ...     ...             ...
# 9995   9996          Love               25    Male    Postgraduate
# 9996   9997      Arranged               31  Female          School
# 9997   9998          Love               22    Male        Graduate
# 9998   9999      Arranged               39    Male    Postgraduate
# 9999  10000      Arranged               36    Male          School
#
#      Caste_Match Religion Parental_Approval Urban_Rural Dowry_Exchanged  \
# 0      Different    Hindu                No       Urban              No
# ...

# %%
df['Marriage_Type'].value_counts()
# Out:
# Marriage_Type
# Arranged    6022
# Love        3978
# Name: count, dtype: int64

# %%
df['Marriage_Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Marriage_Type'>

# %%
df['Marriage_Type'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    5109
# Male      4891
# Name: count, dtype: int64

# %%
df.Gender.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.Gender.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Education_Level'].value_counts()
# Out:
# Education_Level
# Graduate        3943
# School          3073
# Postgraduate    2018
# PhD              966
# Name: count, dtype: int64

# %%
df['Education_Level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Education_Level'>

# %%
df['Education_Level'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Caste_Match'].value_counts()
# Out:
# Caste_Match
# Same         7071
# Different    2929
# Name: count, dtype: int64

# %%
df['Caste_Match'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Caste_Match'>

# %%
df['Caste_Match'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Religion'].value_counts()
# Out:
# Religion
# Hindu        6034
# Muslim       1939
# Christian     990
# Others        531
# Sikh          506
# Name: count, dtype: int64

# %%
df['Religion'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Religion'>

# %%
df['Religion'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Parental_Approval'].value_counts()
# Out:
# Parental_Approval
# Yes        7014
# Partial    1953
# No         1033
# Name: count, dtype: int64

# %%
df['Parental_Approval'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parental_Approval'>

# %%
df['Parental_Approval'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Urban_Rural'].value_counts()
# Out:
# Urban_Rural
# Urban    6046
# Rural    3954
# Name: count, dtype: int64

# %%
df['Urban_Rural'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Urban_Rural'>

# %%
df['Urban_Rural'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Dowry_Exchanged'].value_counts()
# Out:
# Dowry_Exchanged
# No               6002
# Yes              2996
# Not Disclosed    1002
# Name: count, dtype: int64

# %%
df['Dowry_Exchanged'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Dowry_Exchanged'>

# %%
df['Dowry_Exchanged'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Marital_Satisfaction'].value_counts()
# Out:
# Marital_Satisfaction
# Medium    5001
# High      2993
# Low       2006
# Name: count, dtype: int64

# %%
df['Marital_Satisfaction'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Marital_Satisfaction'>

# %%
df['Marital_Satisfaction'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Divorce_Status'].value_counts()
# Out:
# Divorce_Status
# No     8999
# Yes    1001
# Name: count, dtype: int64

# %%
df['Divorce_Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Divorce_Status'>

# %%
df['Divorce_Status'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Children_Count'].value_counts()
# Out:
# Children_Count
# 1    1731
# 3    1698
# 4    1680
# 2    1654
# 5    1647
# 0    1590
# Name: count, dtype: int64

# %%
df['Children_Count'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Children_Count'>

# %%
df['Children_Count'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Income_Level'].value_counts()
# Out:
# Income_Level
# Middle    4983
# Low       2994
# High      2023
# Name: count, dtype: int64

# %%
df['Income_Level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income_Level'>

# %%
df['Income_Level'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Spouse_Working'].value_counts()
# Out:
# Spouse_Working
# Yes    5047
# No     4953
# Name: count, dtype: int64

# %%
df['Spouse_Working'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Spouse_Working'>

# %%
df['Spouse_Working'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Inter-Caste'].value_counts()
# Out:
# Inter-Caste
# No     7032
# Yes    2968
# Name: count, dtype: int64

# %%
df['Inter-Caste'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inter-Caste'>

# %%
df['Inter-Caste'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Inter-Religion'].value_counts()
# Out:
# Inter-Religion
# No     7972
# Yes    2028
# Name: count, dtype: int64

# %%
df['Inter-Religion'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inter-Religion'>

# %%
df['Inter-Religion'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Bivariate

# %%
df
# Out:
#          ID Marriage_Type  Age_at_Marriage  Gender Education_Level  \
# 0         1          Love               23    Male        Graduate
# 1         2          Love               28  Female          School
# 2         3      Arranged               39    Male    Postgraduate
# 3         4      Arranged               26  Female          School
# 4         5          Love               32  Female        Graduate
# ...     ...           ...              ...     ...             ...
# 9995   9996          Love               25    Male    Postgraduate
# 9996   9997      Arranged               31  Female          School
# 9997   9998          Love               22    Male        Graduate
# 9998   9999      Arranged               39    Male    Postgraduate
# 9999  10000      Arranged               36    Male          School
#
#      Caste_Match Religion Parental_Approval Urban_Rural Dowry_Exchanged  \
# 0      Different    Hindu                No       Urban              No
# ...

# %%
pd.crosstab(df['Marriage_Type'], df.Gender,normalize='columns')*100
# Out:
# Gender            Female       Male
# Marriage_Type
# Arranged       59.913877  60.539767
# Love           40.086123  39.460233

# %%
pd.crosstab(df['Marriage_Type'], df.Education_Level,normalize='columns')*100
# Out:
# Education_Level   Graduate        PhD  Postgraduate     School
# Marriage_Type
# Arranged         59.396399  61.283644     59.613479  61.340709
# Love             40.603601  38.716356     40.386521  38.659291

# %%
pd.crosstab(df['Marriage_Type'], df.Caste_Match,normalize='columns')*100
# Out:
# Caste_Match    Different       Same
# Marriage_Type
# Arranged       59.713213  60.429925
# Love           40.286787  39.570075

# %%
pd.crosstab(df['Marriage_Type'], df.Religion,normalize='columns')*100
# Out:
# Religion       Christian      Hindu    Muslim     Others       Sikh
# Marriage_Type
# Arranged       62.727273  60.324826  59.61836  58.003766  58.695652
# Love           37.272727  39.675174  40.38164  41.996234  41.304348

# %%
pd.crosstab(df['Marriage_Type'], df.Parental_Approval,normalize='columns')*100
# Out:
# Parental_Approval         No  Partial        Yes
# Marriage_Type
# Arranged           56.824782  60.9319  60.521814
# Love               43.175218  39.0681  39.478186

# %%
pd.crosstab(df['Marriage_Type'], df['Inter-Caste'],normalize='columns')*100
# Out:
# Inter-Caste           No        Yes
# Marriage_Type
# Arranged       60.452218  59.669811
# Love           39.547782  40.330189

# %%
pd.crosstab(df['Marriage_Type'], df['Inter-Religion'],normalize='columns')*100
# Out:
# Inter-Religion         No        Yes
# Marriage_Type
# Arranged        60.135474  60.552268
# Love            39.864526  39.447732

# %%
sns.kdeplot(df[df["Marriage_Type"] == "Arranged"]["Age_at_Marriage"], fill=True, label="Arranged", color="green", alpha=0.5)
sns.kdeplot(df[df["Marriage_Type"] == "Love"]["Age_at_Marriage"], fill=True, label="Love", color="red", alpha=0.5)
plt.xlabel("Age_at_Marriage")
plt.ylabel("Density")
plt.title("KDE Plot of Age_at_Marriage vs. Marriage_Type")
plt.legend()
plt.show()

# %%
sns.kdeplot(df[df["Marriage_Type"] == "Arranged"]["Years_Since_Marriage"], fill=True, label="Arranged", color="green", alpha=0.5)
sns.kdeplot(df[df["Marriage_Type"] == "Love"]["Years_Since_Marriage"], fill=True, label="Love", color="red", alpha=0.5)
plt.xlabel("Years_Since_Marriage")
plt.ylabel("Density")
plt.title("KDE Plot of Years_Since_Marriage vs. Marriage_Type")
plt.legend()
plt.show()

# %%
df.groupby('Inter-Caste')['Age_at_Marriage'].mean().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Inter-Caste')
plt.ylabel('Mean Age_at_Marriage')
plt.title('Bar Plot of Mean Age_at_Marriage vs Inter-Caste')

plt.show()

# %%
df.groupby('Inter-Caste')['Years_Since_Marriage'].mean().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Inter-Caste')
plt.ylabel('Mean Years_Since_Marriage')
plt.title('Bar Plot of Mean Years_Since_Marriagee vs Inter-Caste')

plt.show()

# %%
sns.scatterplot(x='Age_at_Marriage', y='Years_Since_Marriage', data=df, color='blue', alpha=0.7)
plt.xlabel('Age_at_Marriage')
plt.ylabel('Years_Since_Marriage')
plt.title('Scatter Plot of Age_at_Marriage vs Years_Since_Marriage')
plt.show()

# %%
# PMF AND PDF

# %%
df
# Out:
#          ID Marriage_Type  Age_at_Marriage  Gender Education_Level  \
# 0         1          Love               23    Male        Graduate
# 1         2          Love               28  Female          School
# 2         3      Arranged               39    Male    Postgraduate
# 3         4      Arranged               26  Female          School
# 4         5          Love               32  Female        Graduate
# ...     ...           ...              ...     ...             ...
# 9995   9996          Love               25    Male    Postgraduate
# 9996   9997      Arranged               31  Female          School
# 9997   9998          Love               22    Male        Graduate
# 9998   9999      Arranged               39    Male    Postgraduate
# 9999  10000      Arranged               36    Male          School
#
#      Caste_Match Religion Parental_Approval Urban_Rural Dowry_Exchanged  \
# 0      Different    Hindu                No       Urban              No
# ...

# %%
pmf_Divorce_Status = df['Divorce_Status'].value_counts(normalize=True)
print(pmf_Divorce_Status)
# Out:
# Divorce_Status
# No     0.8999
# Yes    0.1001
# Name: proportion, dtype: float64

# %%
pmf_Divorce_Status.plot(kind='bar')
# Out:
# <Axes: xlabel='Divorce_Status'>

# %%
sns.kdeplot(data = df , x = 'Age_at_Marriage' , hue = 'Marriage_Type')
# Out:
# <Axes: xlabel='Age_at_Marriage', ylabel='Density'>

# %%
sns.kdeplot(df.Age_at_Marriage)
# Out:
# <Axes: xlabel='Age_at_Marriage', ylabel='Density'>

# %%
temp=sorted(df.Age_at_Marriage.tolist())

# %%
x = np.random.uniform(low = 0 , high =1 , size = 1000)

# %%
plt.hist(x)
# Out:
# (array([ 99., 102.,  91., 115.,  96.,  77., 105., 111.,  87., 117.]),
#  array([2.45087734e-04, 9.99662838e-02, 1.99687480e-01, 2.99408676e-01,
#         3.99129872e-01, 4.98851068e-01, 5.98572264e-01, 6.98293460e-01,
#         7.98014656e-01, 8.97735852e-01, 9.97457048e-01]),
#  <BarContainer object of 10 artists>)

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats

# %%
params = stats.uniform.fit(x)
dist = stats.uniform(loc = params[0] , scale = params[1])

# %%
params
# Out:
# (0.00024508773411779927, 0.9972119606428351)

# %%
fig= sm.qqplot(x , dist = dist , line = '45')

# %%
sns.kdeplot(df['Years_Since_Marriage'])
# Out:
# <Axes: xlabel='Years_Since_Marriage', ylabel='Density'>

# %%
temp=sorted(df['Years_Since_Marriage'].tolist())

# %%
x = np.random.uniform(low = 0 , high =1 , size = 1000)

# %%
plt.hist(x)
# Out:
# (array([102., 106., 113.,  98.,  97., 100.,  96., 100., 100.,  88.]),
#  array([0.00215733, 0.10189246, 0.20162758, 0.30136271, 0.40109783,
#         0.50083295, 0.60056808, 0.7003032 , 0.80003833, 0.89977345,
#         0.99950858]),
#  <BarContainer object of 10 artists>)

# %%
import scipy.stats as stats

# %%
params = stats.uniform.fit(x)
dist = stats.uniform(loc = params[0] , scale = params[1])

# %%
params
# Out:
# (0.0021573305147646327, 0.9973512483353825)

# %%
fig= sm.qqplot(x , dist = dist , line = '45')

# %%
#logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('marriage_data_india.csv')

# %%
df
# Out:
#          ID Marriage_Type  Age_at_Marriage  Gender Education_Level  \
# 0         1          Love               23    Male        Graduate
# 1         2          Love               28  Female          School
# 2         3      Arranged               39    Male    Postgraduate
# 3         4      Arranged               26  Female          School
# 4         5          Love               32  Female        Graduate
# ...     ...           ...              ...     ...             ...
# 9995   9996          Love               25    Male    Postgraduate
# 9996   9997      Arranged               31  Female          School
# 9997   9998          Love               22    Male        Graduate
# 9998   9999      Arranged               39    Male    Postgraduate
# 9999  10000      Arranged               36    Male          School
#
#      Caste_Match Religion Parental_Approval Urban_Rural Dowry_Exchanged  \
# 0      Different    Hindu                No       Urban              No
# ...

# %%
df.Marriage_Type = df.Marriage_Type.map({"Love":0 , "Arranged":1 })

# %%
df.Gender = df.Gender.map({"Male":0 , "Female":1 })
df.Education_Level = df.Education_Level.map({"School":0 , "Graduate":1, "Postgraduate":2, "PhD":3 })

# %%
df.Caste_Match = df.Caste_Match.map({"Different":0 , "Same":1 })
df.Religion = df.Religion.map({"Hindu":0 , "Muslim":1 ,"Christian":2,"Sikh":3, "Others":4})

# %%
import pandas as pd

# Replace categorical values with numerical values
df["Dowry_Exchanged"] = df["Dowry_Exchanged"].replace({
    "Yes": 1, 
    "No": 0, 
    "Not Disclosed": -1  
})


df["Dowry_Exchanged"].fillna(-1, inplace=True)  


df["Dowry_Exchanged"] = df["Dowry_Exchanged"].astype(int)


print(df["Dowry_Exchanged"].head())
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Dowry_Exchanged, dtype: int64

# %%
df.Parental_Approval = df.Parental_Approval.map({"No":0 , "Yes":1,"Partial":2 })
df.Urban_Rural = df.Urban_Rural.map({"Urban":0 , "Rural":1 })
df.Marital_Satisfaction = df.Marital_Satisfaction.map({"Low":0 , "High":1,"Medium":2 })
df.Divorce_Status = df.Divorce_Status.map({"No":0 , "Yes":1 })
df.Spouse_Working = df.Spouse_Working.map({"No":0 , "Yes":1 })
df['Inter-Caste'] = df['Inter-Caste'].map({"No":0 , "Yes":1 })
df['Inter-Religion'] = df['Inter-Religion'].map({"No":0 , "Yes":1 })

# %%
df.Income_Level = df.Income_Level.map({"Low":0 , "Middle":1,"High":2 })

# %%
df
# Out:
#          ID  Marriage_Type  Age_at_Marriage  Gender  Education_Level  \
# 0         1              0               23       0                1
# 1         2              0               28       1                0
# 2         3              1               39       0                2
# 3         4              1               26       1                0
# 4         5              0               32       1                1
# ...     ...            ...              ...     ...              ...
# 9995   9996              0               25       0                2
# 9996   9997              1               31       1                0
# 9997   9998              0               22       0                1
# 9998   9999              1               39       0                2
# 9999  10000              1               36       0                0
#
#       Caste_Match  Religion  Parental_Approval  Urban_Rural  Dowry_Exchanged  \
# ...

# %%
x = df.drop(columns=['Marriage_Type'])  # Independent Variables
y = df['Marriage_Type']

# %%
from sklearn.model_selection import train_test_split , GridSearchCV
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
classifier  = LogisticRegression()

# %%
parameter = {"penalty":["l1" ,"l2" , "elasticnet"] , "C":[1,2,3,4,56,5,7,9,30,54,60],"max_iter":[100,200,300,400,500]}

# %%
classifier_reg = GridSearchCV(classifier , param_grid = parameter , scoring = "accuracy" , cv = 10)

# %%
classifier_reg.fit(x_train , y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [1, 2, 3, 4, 56, 5, 7, 9, 30, 54, 60],
#                          'max_iter': [100, 200, 300, 400, 500],
#                          'penalty': ['l1', 'l2', 'elasticnet']},
#              scoring='accuracy')

# %%
print(classifier_reg.best_params_)
# Out:
# {'C': 1, 'max_iter': 100, 'penalty': 'l2'}

# %%
classifier_reg.best_score_
# Out:
# np.float64(0.6028)

# %%
y_pred = classifier_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score , classification_report

# %%
accuracy_score(y_pred , y_test)
# Out:
# 0.6004

# %%
print(classification_report(y_pred ,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.60      0.75      2500
#
#     accuracy                           0.60      2500
#    macro avg       0.50      0.30      0.38      2500
# weighted avg       1.00      0.60      0.75      2500

# %%
# DECISION TREE

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df
# Out:
#          ID Marriage_Type  Age_at_Marriage  Gender Education_Level  \
# 0         1          Love               23    Male        Graduate
# 1         2          Love               28  Female          School
# 2         3      Arranged               39    Male    Postgraduate
# 3         4      Arranged               26  Female          School
# 4         5          Love               32  Female        Graduate
# ...     ...           ...              ...     ...             ...
# 9995   9996          Love               25    Male    Postgraduate
# 9996   9997      Arranged               31  Female          School
# 9997   9998          Love               22    Male        Graduate
# 9998   9999      Arranged               39    Male    Postgraduate
# 9999  10000      Arranged               36    Male          School
#
#      Caste_Match Religion Parental_Approval Urban_Rural Dowry_Exchanged  \
# 0      Different    Hindu                No       Urban              No
# ...

# %%
df.Marriage_Type = df.Marriage_Type.map({"Love":0 , "Arranged":1 })

# %%
df.Gender = df.Gender.map({"Male":0 , "Female":1 })
df.Education_Level = df.Education_Level.map({"School":0 , "Graduate":1, "Postgraduate":2, "PhD":3 })

# %%
df.Caste_Match = df.Caste_Match.map({"Different":0 , "Same":1 })
df.Religion = df.Religion.map({"Hindu":0 , "Muslim":1 ,"Christian":2,"Sikh":3, "Others":4})

# %%
import pandas as pd

# Replace categorical values with numerical values
df["Dowry_Exchanged"] = df["Dowry_Exchanged"].replace({
    "Yes": 1, 
    "No": 0, 
    "Not Disclosed": -1  # You can choose -1, or handle it differently
})

# Handle NaN values before type conversion
df["Dowry_Exchanged"].fillna(-1, inplace=True)  # Replace NaN with -1 (or another strategy)

# Convert column to integer type
df["Dowry_Exchanged"] = df["Dowry_Exchanged"].astype(int)

# Display updated column
print(df["Dowry_Exchanged"].head())
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Dowry_Exchanged, dtype: int64

# %%
df.Parental_Approval = df.Parental_Approval.map({"No":0 , "Yes":1,"Partial":2 })
df.Urban_Rural = df.Urban_Rural.map({"Urban":0 , "Rural":1 })
df.Marital_Satisfaction = df.Marital_Satisfaction.map({"Low":0 , "High":1,"Medium":2 })
df.Divorce_Status = df.Divorce_Status.map({"No":0 , "Yes":1 })
df.Spouse_Working = df.Spouse_Working.map({"No":0 , "Yes":1 })
df['Inter-Caste'] = df['Inter-Caste'].map({"No":0 , "Yes":1 })
df['Inter-Religion'] = df['Inter-Religion'].map({"No":0 , "Yes":1 })

# %%
df.Income_Level = df.Income_Level.map({"Low":0 , "Middle":1,"High":2 })

# %%
df
# Out:
#          ID  Marriage_Type  Age_at_Marriage  Gender  Education_Level  \
# 0         1              0               23       0                1
# 1         2              0               28       1                0
# 2         3              1               39       0                2
# 3         4              1               26       1                0
# 4         5              0               32       1                1
# ...     ...            ...              ...     ...              ...
# 9995   9996              0               25       0                2
# 9996   9997              1               31       1                0
# 9997   9998              0               22       0                1
# 9998   9999              1               39       0                2
# 9999  10000              1               36       0                0
#
#       Caste_Match  Religion  Parental_Approval  Urban_Rural  Dowry_Exchanged  \
# ...

# %%
x = df.drop(columns=['Marriage_Type'])  # Independent Variables
y = df['Marriage_Type']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test  = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier(max_depth=2)
treemodel.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn import tree
plt.figure(figsize = (20,15))
tree.plot_tree(treemodel, filled = True)
plt.tight_layout()

# %%
tree_model = DecisionTreeClassifier(max_depth = 2)
tree_model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
tree.plot_tree(tree_model , filled = True)
plt.tight_layout()

# %%
y1 = treemodel.predict(x_test)
y2 = tree_model.predict(x_test)

# %%
from sklearn.metrics import classification_report , accuracy_score

# %%
print(classification_report(y1 , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.60      0.01         5
#            1       1.00      0.59      0.74      1995
#
#     accuracy                           0.59      2000
#    macro avg       0.50      0.60      0.38      2000
# weighted avg       1.00      0.59      0.74      2000

# %%
print(classification_report(y2 , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.60      0.01         5
#            1       1.00      0.59      0.74      1995
#
#     accuracy                           0.59      2000
#    macro avg       0.50      0.60      0.38      2000
# weighted avg       1.00      0.59      0.74      2000

# %%
print(accuracy_score(y1 , y_test))
print(accuracy_score(y2 , y_test))
# Out:
# 0.593
# 0.593
