# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Disease_symptom_and_patient_profile_dataset.csv')

# %%
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
df.columns
# Out:
# Index(['Disease', 'Fever', 'Cough', 'Fatigue', 'Difficulty Breathing', 'Age',
#        'Gender', 'Blood Pressure', 'Cholesterol Level', 'Outcome Variable'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Disease                 0
# Fever                   0
# Cough                   0
# Fatigue                 0
# Difficulty Breathing    0
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Outcome Variable        0
# dtype: int64

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# # NUMERICAL

# %%
df.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Age.describe()
# Out:
# count    349.000000
# mean      46.323782
# std       13.085090
# min       19.000000
# 25%       35.000000
# 50%       45.000000
# 75%       55.000000
# max       90.000000
# Name: Age, dtype: float64

# %%
df.Age.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.Age.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.Age.skew()
# Out:
# np.float64(0.5674050307810211)

# %%
df.Age.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # CATEGORICAL

# %%
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
df.Disease.value_counts()
# Out:
# Disease
# Asthma               23
# Stroke               16
# Osteoporosis         14
# Diabetes             10
# Hypertension         10
#                      ..
# Schizophrenia         1
# Gout                  1
# Testicular Cancer     1
# Tonsillitis           1
# Williams Syndrome     1
# Name: count, Length: 116, dtype: int64

# %%
df.Disease.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Disease.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Disease'>

# %%
df.Disease.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Fever.value_counts()
# Out:
# Fever
# Yes    175
# No     174
# Name: count, dtype: int64

# %%
df.Fever.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Fever.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Fever'>

# %%
df.Fever.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Fatigue.value_counts()
# Out:
# Fatigue
# Yes    242
# No     107
# Name: count, dtype: int64

# %%
df.Fatigue.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Fatigue.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Fatigue'>

# %%
df.Fatigue.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Cough.value_counts()
# Out:
# Cough
# No     182
# Yes    167
# Name: count, dtype: int64

# %%
df.Cough.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Cough.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cough'>

# %%
df.Cough.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    176
# Male      173
# Name: count, dtype: int64

# %%
df.Gender.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Gender.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.Gender.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Difficulty Breathing'].value_counts()
# Out:
# Difficulty Breathing
# No     261
# Yes     88
# Name: count, dtype: int64

# %%
df['Difficulty Breathing'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Difficulty Breathing'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Difficulty Breathing'>

# %%
df['Difficulty Breathing'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Cholesterol Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Cholesterol Level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cholesterol Level'>

# %%
df['Cholesterol Level'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Blood Pressure'].value_counts()
# Out:
# Blood Pressure
# High      167
# Normal    164
# Low        18
# Name: count, dtype: int64

# %%
df['Blood Pressure'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Blood Pressure'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Blood Pressure'>

# %%
df['Blood Pressure'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Outcome Variable'].value_counts()
# Out:
# Outcome Variable
# Positive    186
# Negative    163
# Name: count, dtype: int64

# %%
df['Outcome Variable'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Outcome Variable'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Outcome Variable'>

# %%
df['Outcome Variable'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Bivariate

# %%
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
pd.crosstab(df['Outcome Variable'], df.Fever,normalize='columns')*100
# Out:
# Fever                    No        Yes
# Outcome Variable
# Negative          55.747126  37.714286
# Positive          44.252874  62.285714

# %%
pd.crosstab(df['Outcome Variable'], df.Cough,normalize='columns')*100
# Out:
# Cough                    No        Yes
# Outcome Variable
# Negative          46.153846  47.305389
# Positive          53.846154  52.694611

# %%
pd.crosstab(df['Outcome Variable'], df.Fatigue,normalize='columns')*100
# Out:
# Fatigue                  No       Yes
# Outcome Variable
# Negative          57.009346  42.14876
# Positive          42.990654  57.85124

# %%
pd.crosstab(df['Outcome Variable'], df['Difficulty Breathing'],normalize='columns')*100
# Out:
# Difficulty Breathing         No        Yes
# Outcome Variable
# Negative              49.425287  38.636364
# Positive              50.574713  61.363636

# %%
pd.crosstab(df['Outcome Variable'], df['Blood Pressure'],normalize='columns')*100
# Out:
# Blood Pressure         High        Low     Normal
# Outcome Variable
# Negative          37.724551  77.777778  52.439024
# Positive          62.275449  22.222222  47.560976

# %%
pd.crosstab(df['Outcome Variable'], df['Cholesterol Level'],normalize='columns')*100
# Out:
# Cholesterol Level       High        Low     Normal
# Outcome Variable
# Negative           30.722892  70.588235  59.060403
# Positive           69.277108  29.411765  40.939597

# %%
pd.crosstab(df['Outcome Variable'], df.Gender,normalize='columns')*100
# Out:
# Gender               Female       Male
# Outcome Variable
# Negative          39.772727  53.757225
# Positive          60.227273  46.242775

# %%
sns.kdeplot(df[df["Outcome Variable"] == "Positive"]["Age"], fill=True, label="Positive", color="green", alpha=0.5)
sns.kdeplot(df[df["Outcome Variable"] == "Negative"]["Age"], fill=True, label="Negative", color="red", alpha=0.5)
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("KDE Plot of Age vs. Outcome Variable")
plt.legend()
plt.show()

# %%
df.groupby('Outcome Variable')['Age'].mean().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Outcome Variable')
plt.ylabel('Mean Age')
plt.title('Bar Plot of Mean Age vsOutcome Variable')

plt.show()

# %%
df.groupby('Fever')['Age'].mean().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Fever')
plt.ylabel('Mean Age')
plt.title('Bar Plot of Mean Age vs Fever')

plt.show()

# %%
sns.kdeplot(data = df , x = 'Age' , hue = 'Outcome Variable')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# NORMALITY

# %%
sns.kdeplot(df.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.Age.mean()
# Out:
# np.float64(46.32378223495702)

# %%
df.Age.std()
# Out:
# np.float64(13.085089852889405)

# %%
x = (df.Age - df.Age.mean())/df.Age.std()
x
# Out:
# 0     -2.088162
# 1     -1.629624
# 2     -1.629624
# 3     -1.629624
# 4     -1.629624
#          ...
# 344    2.573633
# 345    2.955747
# 346    2.955747
# 347    3.337862
# 348    3.337862
# Name: Age, Length: 349, dtype: float64

# %%
sns.kdeplot(x)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
x.mean()
# Out:
# np.float64(-2.443126885135015e-16)

# %%
x.std()
# Out:
# np.float64(0.9999999999999999)

# %%
x.skew()
# Out:
# np.float64(0.5674050307810224)

# %%
# QQ PLOT

# %%
sns.kdeplot(df.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
temp = sorted(df.Age.tolist())

# %%
samples = np.random.normal(loc = 0 , scale = 1 , size = 1000)

# %%
y_quant = []

for i in range(1 , 101):
    y_quant.append(np.percentile(temp,i))

# %%
x_quant = []
for i in range(1,101):
    x_quant.append(np.percentile(samples , i))

# %%
sns.scatterplot(y=y_quant ,x= x_quant)
# Out:
# <Axes: >

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
fig = sm.qqplot(df.Age , line = '45' , fit = True)

# %%
# LOGISTIC REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Disease_symptom_and_patient_profile_dataset.csv')

# %%
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
df.isnull().sum()
# Out:
# Disease                 0
# Fever                   0
# Cough                   0
# Fatigue                 0
# Difficulty Breathing    0
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Outcome Variable        0
# dtype: int64

# %%
df["Disease"] = df["Disease"].astype("category").cat.codes
df["Fever"] = df["Fever"].map({"No": 0, "Yes": 1})
df["Cough"] = df["Cough"].map({"No": 0, "Yes": 1})
df["Fatigue"] = df["Fatigue"].map({"No": 0, "Yes": 1})
df["Difficulty Breathing"] = df["Difficulty Breathing"].map({"No": 0, "Yes": 1})
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})
df["Blood Pressure"] = df["Blood Pressure"].map({"Low": 0, "Normal": 1, "High": 2})
df["Cholesterol Level"] = df["Cholesterol Level"].map({"Low": 0, "Normal": 1, "High": 2})
df["Outcome Variable"] = df["Outcome Variable"].map({"Negative": 0, "Positive": 1})

# %%
x=df.iloc[:,:-1]
y=df['Outcome Variable']

# %%
from sklearn.model_selection import train_test_split , GridSearchCV
x_train , x_test , y_train , y_test = train_test_split(x ,y, test_size = .25 , random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
classifier  = LogisticRegression()

# %%
parameter = {"penalty":["l1" ,"l2" , "elasticnet"] , "C":[1,2,3,4,56,5,7,9,30,54,60],"max_iter":[100,200,300,400,500]}

# %%
classifier_reg = GridSearchCV(classifier , param_grid = parameter , scoring = "accuracy" , cv = 10)

# %%
classifier_reg.fit(x_train , y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [1, 2, 3, 4, 56, 5, 7, 9, 30, 54, 60],
#                          'max_iter': [100, 200, 300, 400, 500],
#                          'penalty': ['l1', 'l2', 'elasticnet']},
#              scoring='accuracy')

# %%
print(classifier_reg.best_params_)
# Out:
# {'C': 1, 'max_iter': 100, 'penalty': 'l2'}

# %%
classifier_reg.best_score_
# Out:
# np.float64(0.701851851851852)

# %%
y_pred = classifier_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score , classification_report

# %%
accuracy_score(y_pred , y_test)
# Out:
# 0.6022727272727273

# %%
# Decision Tree

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Disease_symptom_and_patient_profile_dataset.csv')

# %%
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
df.isnull().sum()
# Out:
# Disease                 0
# Fever                   0
# Cough                   0
# Fatigue                 0
# Difficulty Breathing    0
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Outcome Variable        0
# dtype: int64

# %%
df["Disease"] = df["Disease"].astype("category").cat.codes
df["Fever"] = df["Fever"].map({"No": 0, "Yes": 1})
df["Cough"] = df["Cough"].map({"No": 0, "Yes": 1})
df["Fatigue"] = df["Fatigue"].map({"No": 0, "Yes": 1})
df["Difficulty Breathing"] = df["Difficulty Breathing"].map({"No": 0, "Yes": 1})
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})
df["Blood Pressure"] = df["Blood Pressure"].map({"Low": 0, "Normal": 1, "High": 2})
df["Cholesterol Level"] = df["Cholesterol Level"].map({"Low": 0, "Normal": 1, "High": 2})
df["Outcome Variable"] = df["Outcome Variable"].map({"Negative": 0, "Positive": 1})

# %%
df
# Out:
#      Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0         56      1      0        1                     1   19       1
# 1         24      0      1        1                     0   25       1
# 2         37      0      1        1                     0   25       1
# 3          6      1      1        0                     1   25       0
# 4          6      1      1        0                     1   25       0
# ..       ...    ...    ...      ...                   ...  ...     ...
# 344      101      1      0        1                     0   80       1
# 345      101      1      0        1                     0   85       0
# 346      101      1      0        1                     0   85       0
# 347      101      1      0        1                     0   90       1
# 348      101      1      0        1                     0   90       1
#
#      Blood Pressure  Cholesterol Level  Outcome Variable
# 0                 0                  1                 1
# ...

# %%
x = df.iloc[:,:-1]
y = df['Outcome Variable']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test  = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier(max_depth=2)
treemodel.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn import tree
plt.figure(figsize = (20,15))
tree.plot_tree(treemodel, filled = True)
plt.tight_layout()

# %%
tree_model = DecisionTreeClassifier(max_depth = 2)
tree_model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
tree.plot_tree(tree_model , filled = True)
plt.tight_layout()

# %%
y1 = treemodel.predict(x_test)
y2 = tree_model.predict(x_test)

# %%
from sklearn.metrics import classification_report , accuracy_score

# %%
print(classification_report(y1 , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        44
#            1       0.45      0.69      0.55        26
#
#     accuracy                           0.57        70
#    macro avg       0.59      0.60      0.57        70
# weighted avg       0.63      0.57      0.58        70

# %%
print(classification_report(y2 , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        44
#            1       0.45      0.69      0.55        26
#
#     accuracy                           0.57        70
#    macro avg       0.59      0.60      0.57        70
# weighted avg       0.63      0.57      0.58        70

# %%
print(accuracy_score(y1 , y_test))
print(accuracy_score(y2 , y_test))
# Out:
# 0.5714285714285714
# 0.5714285714285714
